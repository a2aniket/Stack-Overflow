# %%
import matplotlib.pyplot as plt
import numpy as np
xinput=[[10,20,30,40,50,60],[10,20,30,40,50,60],[10,20,30,40,50,60]]
bins = np.linspace(0, 2, 40)
plt.hist(xinput,alpha=0.9)
plt.legend(['Red', 'Blue','Green'])
plt.axis([1,20,0,20])
plt.show()
